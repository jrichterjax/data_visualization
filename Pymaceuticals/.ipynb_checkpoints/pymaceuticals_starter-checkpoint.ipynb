# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - The following data indicates that Capomulin outperformed all other drug regimens implemented in the study by Pymaceuticals with the exception of Ramicane.
# - Both Capomulin and Ramicane have significantly lower mean tumor volumes, lower variance, and a greater number of observation points (or length of study) than the other drugs tested.
# - The split between male and female observation points was relatively equal.
# - In one particular instance, in the study of mouse l509 who received the Capomulin treatment, the tumor volume initially increased moderately but subsequently decreased significantly before again rising slightly.
# - There is a strong positive correlation between mouse weight and tumor volume.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import statistics

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combined_df = pd.merge(study_results, mouse_metadata, on='Mouse ID', how='left')

# Display the data table for preview
combined_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
mice_count = len(combined_df["Mouse ID"].unique())
mice_count
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
# https://stackoverflow.com/questions/46640945/grouping-by-multiple-columns-to-find-duplicate-rows-pandas
duplicates_df = combined_df[combined_df.duplicated(subset=['Mouse ID','Timepoint'], keep=False)]
duplicate_mouse_id = duplicates_df["Mouse ID"].unique()
duplicate_mouse_id
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_data = combined_df.loc[combined_df["Mouse ID"] == "g989", :]
duplicate_mouse_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = combined_df.loc[combined_df["Mouse ID"] != "g989", :]
clean_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
new_mice_count = len(clean_df["Mouse ID"].unique())
new_mice_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

mean_tumor_volume = clean_df.groupby("Drug Regimen").mean()["Tumor Volume (mm3)"]
median_tumor_volume = clean_df.groupby("Drug Regimen").median()["Tumor Volume (mm3)"]
tumor_volume_variance = clean_df.groupby("Drug Regimen").var()["Tumor Volume (mm3)"]
tumor_volume_std_variation = clean_df.groupby("Drug Regimen").std()["Tumor Volume (mm3)"]
tumor_volume_std_err = clean_df.groupby("Drug Regimen").sem()["Tumor Volume (mm3)"]

summary_statistics = pd.DataFrame({"Mean Tumor Volume":mean_tumor_volume,
                             "Median Tumor Volume":median_tumor_volume,
                             "Tumor Volume Variance":tumor_volume_variance,
                             "Tumor Volume Std. Dev.":tumor_volume_std_variation,
                             "Tumor Volume Std. Err.":tumor_volume_std_err})
summary_statistics
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
clean_df.groupby("Drug Regimen").aggregate({'Tumor Volume (mm3)' : ['mean', 'median', 'var', 'std', 'sem']})
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
drug_observations = clean_df[["Drug Regimen","Mouse ID"]]

grouped_drug_observations = pd.DataFrame(drug_observations.groupby("Drug Regimen").count()["Mouse ID"])

grouped_drug_observations.plot(kind="bar", ylabel="# of Observed Mouse Timepoints", legend=None)

plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
plt.bar(clean_df["Drug Regimen"].unique(),clean_df.groupby("Drug Regimen").count()["Mouse ID"])
plt.xticks(clean_df["Drug Regimen"].unique(), rotation=90)

plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
record_count = clean_df["Mouse ID"].count()

male_df = clean_df.loc[clean_df["Sex"] == "Male", :]
male_total = male_df["Mouse ID"].count()
male_percentage = (male_total / record_count) * 100

female_df = clean_df.loc[clean_df["Sex"] == "Female", :]
female_total = female_df["Mouse ID"].count()
female_percentage = (female_total / record_count) * 100

sex_df = pd.DataFrame({
    "Sex" : ["Male", "Female"],
    "Percentage" : [male_percentage, female_percentage]
})

sex_df = sex_df.set_index("Sex")

sex_df.plot(kind='pie', y='Percentage', ylabel="Sex", autopct="%1.1f%%", legend=None)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sex_percentages = [male_percentage, female_percentage]
labels = ["Male", "Female"]

plt.pie(sex_percentages, labels=labels, autopct="%1.1f%%")

plt.ylabel("Sex")

plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
four_regimen_df = clean_df.loc[(clean_df["Drug Regimen"] == "Capomulin") | 
                               (clean_df["Drug Regimen"] == "Ramicane") | 
                               (clean_df["Drug Regimen"] == "Infubinol") | 
                               (clean_df["Drug Regimen"] == "Ceftamin")]

# Start by getting the last (greatest) timepoint for each mouse
last_timepoint_df = pd.DataFrame(four_regimen_df.groupby("Mouse ID").max()["Timepoint"])

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
# https://stackoverflow.com/questions/41815079/pandas-merge-join-two-data-frames-on-multiple-columns
merged_df = clean_df.merge(last_timepoint_df, on=["Mouse ID" , "Timepoint"])
merged_df
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0      u153          0           45.000000                 0     Ceftamin
# 1      b447          0           45.000000                 0     Ceftamin
# 2      x226          0           45.000000                 0     Ceftamin
# 3      t573          0           45.000000                 0     Ceftamin
# 4      c326          5           36.321346                 0    Infubinol
# ..      ...        ...                 ...               ...          ...
# 95     a644         45           32.978522                 1     Ramicane
# 96     i177         45           33.562402                 3     Ramicane
# 97     r944         45           41.581521                 2    Capomulin
# 98     u364         45           31.023923                 3    Capomulin
# 99     p438         45           61.433892                 1     Ceftamin
#
#        Sex  Age_months  Weight (g)
# 0   Female          11          25
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_list = []

# Locate the rows which contain mice on each drug and get the tumor volumes, # add subset
for treatment in treatments:
             
    tumor_data = merged_df.loc[merged_df["Drug Regimen"] == treatment, "Tumor Volume (mm3)"]
        
    tumor_vol_list.append(tumor_data)
    
    # Calculate the IQR and quantitatively determine if there are any potential outliers.
    # Determine outliers using upper and lower bounds
    quartiles = tumor_data.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
        
    outlier_data = merged_df.loc[(merged_df["Drug Regimen"] == treatment) & ((merged_df["Tumor Volume (mm3)"] < lower_bound) | (merged_df["Tumor Volume (mm3)"] > upper_bound)), "Tumor Volume (mm3)"]        
        
    print(f"{treatment}'s potential outliers: {outlier_data}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 4    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group. 
fig, ax = plt.subplots()

# https://stackoverflow.com/questions/43342564/flier-colors-in-boxplot-with-matplotlib
flierprops = dict(markerfacecolor="red", markersize=12)

ax.boxplot(tumor_vol_list, flierprops=flierprops)

ax.set_xticklabels(treatments)
ax.set_ylabel("Final Tumor Volume (mm3)")

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

single_mouse_df = clean_df.loc[clean_df["Mouse ID"] == "l509"]

x_axis = single_mouse_df["Timepoint"]
y_axis = single_mouse_df["Tumor Volume (mm3)"]

plt.plot(x_axis, y_axis)

plt.title("Capomulin treatment of mouse l509")
plt.xlabel("Timepoint (days)")
# plt.ylabel("Tumor Volume (mm3)")

plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
Capomulin_df = clean_df.loc[clean_df["Drug Regimen"] == "Capomulin"]

x_axis = Capomulin_df.groupby("Mouse ID").mean()["Weight (g)"]
y_axis = Capomulin_df.groupby("Mouse ID").mean()["Tumor Volume (mm3)"]

plt.scatter(x_axis, y_axis)

plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
Capomulin_df = clean_df.loc[clean_df["Drug Regimen"] == "Capomulin"]

x_values = Capomulin_df.groupby("Mouse ID").mean()["Weight (g)"]
y_values = Capomulin_df.groupby("Mouse ID").mean()["Tumor Volume (mm3)"]

correlation = st.pearsonr(x_values,y_values)
print(f"The correlation between mouse weight and the average tumor volume is {round(correlation[0], 2)}")

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")

plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
